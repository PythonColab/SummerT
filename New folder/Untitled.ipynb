# %%
import tensorflow

# %%
import os
os.path
# Out:
# <module 'ntpath' from 'E:\\Users\\BHANU\\Anaconda3\\lib\\ntpath.py'>

# %%
from pocketsphinx import LiveSpeech
for phrase in LiveSpeech(): print(phrase)
# Out:
# fat
# that and i
# hit
# so
# huh
# and that
# at
# what
# it
# but
# but
# it
# that
# but for now
# but
# it
# it is
# right
# to lose them but
# this is the most notably it
# so
# so
# it
# to to
# it
# so
# but no
# but
# just and
# and
# it are
# and
# i am
#
# what
# and
# but
# but
# and
# it
# at that
# but
# it and
# it
# but
# it i i
# but
# good it
# but
# it is
# but it is
# and
# what
# but
# but
# but
# it
# what
# but
# it
# and
# did he
#
# but
# dat
# this
# it is
# but
# but
# to do it
# and
# and
# and
# but
# the
# it is
# but
# but
# it
# it is
# it it does
# it is just
# what
# but
# and hit
# and
# did he
# the
# and
# and
# but
# and
# what in
# it is
# and you
# so
# i'd you
# but
# citizens
# as an
# but at this
# but
# but
# but
# and an
# it the do
# does it
# that is
# but
# but
# and
# it
# and
# to that
# and
# to
# that
# good
# and
# but
# two
# and
# and
# used to
# edit
# one
# but
# what is that
# that does it
# and
# but
#
# that
# at at
# but
# and
# and in
# but
# it
# it what to
# but
# but it
# what
# but
# it was
#
# but
# that
# what
# but
# it
# it
# at
# but
# but
# but
#
# that it's
# what an a
# none
# and
# and
#
# and
# but
# but
# but
# and the
# that and
# but
# but
# why
# but
# it to that
# that
# one
# what
# that is
# but
# but
# what
# but
# take that
# that
#
# that and
# it it
# yeah
# but
# at this
# the
# and so what
# is long

# %%
from pocketsphinx import AudioFile
for phrase in AudioFile(): print(phrase)
# Out:
# go forward ten meters

# %%
import os
from pocketsphinx import AudioFile, get_model_path, get_data_path

model_path = get_model_path()
data_path = get_data_path()

config = {
    'verbose': False,
    'audio_file': os.path.join(data_path, 'goforward.raw'),
    'buffer_size': 2048,
    'no_search': False,
    'full_utt': False,
    'hmm': os.path.join(model_path, 'en-us'),
    'lm': os.path.join(model_path, 'en-us.lm.bin'),
    'dict': os.path.join(model_path, 'cmudict-en-us.dict')
}

audio = AudioFile(**config)
for phrase in audio:
    print(phrase)
